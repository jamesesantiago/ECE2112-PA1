# %% [markdown]
#  (A) Word Rotation Problem

# %%
text = input("Enter a word")
length = len(text)

def rotate_word(text):
    return (text[1:length:1])+(text[0:1:1])

rotate_word(text)
# Out:
# Enter a word Engineering
# 'ngineeringE'

# %% [markdown]
# (B) Username Builder Problem

# %%
first_name = input("Enter First Name: ")
last_name = input("Enter Last Name: ")

def make_username(first_name, last_name):

    lower_first_name = first_name.lower().replace(" ","")

    lower_last_name = last_name.lower().replace(" ", "")

    username = lower_first_name + "." + lower_last_name

    print(username)

make_username(first_name, last_name)
# Out:
# Enter First Name:  James Eon Marcelo
# Enter Last Name:  Santiago
# jameseonmarcelo.santiago

# %% [markdown]
# (C) Bookend Swap Problem

# %%
def swap_bookends(items):
    
    first, *middle, last = items
    return [last] + middle + [first]

listed_items = input("Please Input Items, Numbers, etc: ").split()

if len(listed_items) <2:
        print("Please Input Atleast 2!!!")
else:

    print ("Swapped Bookends: " , swap_bookends(listed_items))
# Out:
# Please Input Items, Numbers, etc:  1, 2, 3, 4, 5, 6
# Swapped Bookends:  ['6', '2,', '3,', '4,', '5,', '1,']
